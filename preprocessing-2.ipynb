# %%
import pandas as pd
import numpy as np
import time
import string
import re
from IPython.display import clear_output
import requests
import spacy
import gensim
from gensim import corpora
from nltk.corpus import stopwords
import concurrent.futures
#nltk.download("stopwords")

import warnings
warnings.filterwarnings("ignore")

# %%
#!python3 -m spacy download de_core_news_md
nlp = spacy.load('de_core_news_md')

# %%
def preprocess(text, idx):
    text = text.lower()
    print("lower - %s" % (idx))
    
    # remove "&nbsp"
    text = re.sub(r"\&nbsp", "", text)
    # remove urls
    # source: url_extract_pattern from https://uibakery.io/regex-library/url-regex-python
    url_extract_pattern = "https?:\\/\\/(?:www\\.)?[-a-zA-Z0-9@:%._\\+~#=]{1,256}\\.[a-zA-Z0-9()]{1,6}\\b(?:[-a-zA-Z0-9()@:%_\\+.~#?&\\/=]*)"
    text = re.sub(url_extract_pattern, '', text)
    # remvoe "\n"
    text = re.sub(r"[^ ]*\n", "", text)
    # remove file names with commom endings with 4 or 3 digits
    text = re.sub(r"[^ ]*\..{4}|[^ ]*\..{3}", "", text)
    # remove any refs
    text = re.sub(r"[^ ]*ref", "", text)
    # remove -
    text = re.sub(r"-", "", text)
    #remove punctuation thats left
    text = text.translate(str.maketrans('', '', string.punctuation))
    
    # remove stopwords
    text = text.split(" ")
    # source: https://stackoverflow.com/questions/5486337/how-to-remove-stop-words-using-nltk-or-python
    text = [word for word in text if word not in german_stopwords]
    
    # lemmatization
    text_lemma = []

    for ix, word in enumerate(text):
        doc = nlp(word)
        result = ' '.join([x.lemma_ for x in doc]) 
        text_lemma.append(result)
    
    final = [gensim.utils.simple_preprocess(word, deacc = True) for word in text_lemma]
    
    for word in final:
        if len(word) == 0:
            final.remove(word)
    
    final_text = [''.join(word) for word in final]
    final_text = " ".join(final_text)
    print("final - %s" % (idx))
    
    preprocessed_content.update({idx: final_text})
    #preprocessed_content.append(final)

# %%
def get_pages_by_id(id):
    params.update({"pageids": id})
    response = S.get(url = URL, params = params)
    page = response.json()
    content.update({id: page["query"]["pages"][0]["revisions"][0]["slots"]["main"]["content"]})

# %% [markdown]
# ---

# %%
URL = "https://de.wikipedia.org/w/api.php"

# %%
german_stopwords = stopwords.words("german")

# %%
additional_stopwords = ["isbn", "url", "infobox", "dateila", "di"]
for word in additional_stopwords:
    german_stopwords.append(word)

# %%
# request excellent arictles from german wikipedia via wiki api (10 at a time)
S = requests.Session()

params = {
    "action": "query",
    "prop": "revisions",
    "rvprop": "content",
    "rvslots": "*",
    "format": "json",
    "formatversion": 2,
    "srsearch": "incategory:Wikipedia:Exzellent",
    "list": "search",
    "sroffset": 0
}

response = S.get(url = URL, params = params)
data = response.json()

# get ids from excellent articles
ids = []

for entry in data["query"]["search"]:
    ids.append(entry["pageid"])

while data.get("continue"):
    params.update({"sroffset": data["continue"]["sroffset"]})
    
    #print("\n%s" % (PARAMS))
    response = S.get(url = URL, params = params)
    data = response.json()
    
    for entry in data["query"]["search"]:
        ids.append(entry["pageid"])

print("Anzahl gesammelter Exzellenter Artikel: %s" %(len(ids)))

#if DATA['query']['search'][0]['title'] == SEARCHPAGE:
#    print("Your search page '" + SEARCHPAGE + "' exists on English Wikipedia")
# Out:
# Anzahl gesammelter Exzellenter Artikel: 2803

# %%
content = {}
start = time.time()
with concurrent.futures.ThreadPoolExecutor() as executor:
    executor.map(get_pages_by_id, ids)

end = time.time()
dur = end - start
print("DUR: %s" % (dur))
# Out:
# DUR: 77.34979796409607

# %%
len(content)
# Out:
# 2782

# %%
# save requested data in df
df = pd.DataFrame(content.items())
df = df.rename({0: "pageid", 1:"content"}, axis = 1)

# %%
df.head()
# Out:
#     pageid                                            content
# 0     1428  [[Datei:Danimarca XIII secolo, plinio historia...
# 1     2677  {{Begriffsklärungshinweis}}\n{{Infobox Staat\n...
# 2     2391  {{Dieser Artikel|behandelt das Land – zu ander...
# 3   490244  {{Begriffsklärungshinweis}}\n[[Datei:La scuola...
# 4  3221050  {{Begriffsklärungshinweis}}\n{{Infobox Ort in ...

# %%
content = df["content"][:5]
content
# Out:
# 0    [[Datei:Danimarca XIII secolo, plinio historia...
# 1    {{Begriffsklärungshinweis}}\n{{Infobox Staat\n...
# 2    {{Dieser Artikel|behandelt das Land – zu ander...
# 3    {{Begriffsklärungshinweis}}\n[[Datei:La scuola...
# 4    {{Begriffsklärungshinweis}}\n{{Infobox Ort in ...
# Name: content, dtype: object

# %%
ids = df["pageid"][:5]
ids
# Out:
# 0       1428
# 1       2677
# 2       2391
# 3     490244
# 4    3221050
# Name: pageid, dtype: int64

# %%
preprocessed_content = {}
start = time.time()
with concurrent.futures.ThreadPoolExecutor() as executor:
    executor.map(preprocess, content, ids)
    
end = time.time()
dur = end - start
print("DUR: %s" % (dur))
# Out:
# lower - 1428lower - 2677
#
# lower - 2391
# lower - 490244
# lower - 3221050
# final - 490244
# final - 3221050
# final - 1428
# final - 2677
# final - 2391
# DUR: 213.14298605918884

# %%
preprocessed_content
# Out:
# {490244: 'scuola raffaelraffael schule athen idealisierten darstellung grundervater abendlandisch ohl seit platon sache schriftlich abhandlung angeregen gesprach heute wichtig bestandteil philosophisch ersicht bedeutend philosoph philosophie grcsφιλοσοφια philosophia wortlich lieb weisheit versuchen welt menschlich existenz ergrunden deuten unterscheiden philosophie dadurch oft speziell gebiet bestimmen methodologie begrenzen art fragestellung besonderer vielfaltig artikel gehen westlich abendlandisch philosophie rhunderen antik griechenland ht behandeln abendlandisch philosophie mannigfaltig zusammenhang stehend tradition judisch islamisch philosophie sowie ursprunglich unabhangig tradition afrikanisch ostlich philosophie antikeantik philosophie entfalten systematisch orientiert laufen jahrhundert differenziert unterschiedlich methode disziplin wissenschaft direkt mittelbar philosophie teil abgrenzung irrationale religios weltbildern kerngebieen philosophie logik wissenschaft folgerichtige denkens ethik wissenschaft rechter handelns metaphysik wissenschaft erster grunde seins tere grunddisziplin moglichkeit allgemein ziell erkenntnisweise unterschiedlich einfuhrung geben problem unzureichend hilfe exakten wissenschaft bearbeiten lassen fragen etwa gut bose gerechtigkeit bedeuten gott geben mensch unsterblich seele besit
#  2391: 'land bedeutung sehen indien nameamtssprach span stylefontsizepxlanghiभरत गणरजयspan span republic of india span transkription bharat ganarajya span namedeutsch republik bildflagge flag of artikelflagge flagge bildwappe emblem of artikelwappe wappe wappenopt wahlspruch सतयमव जयत satyameva jayatebr sanskrit allein wahrheit amtssprach hindi englisch amtssprachen unionbr weit offiziell anerkannt sprechen dienen regional ebene teils mehrspaltig liste breiteem anzahl abstand assamesisch bengalisch bodo sprachebodobr dogribr gujaratibr kannadabr kashmiribr konkanibr maithilibr malayalambr marathibr meiteibr nepalibr oriyabr panjabibr santalibr sanskritbr sindhibr tamilbr telugubr hauptstadt staat regierungsform parlamentarisch bundesstaat foderal staatsoberhaupt prasident republik draupadi regierungschef premierminister narendra flache smallliste staat territorien census of india primary census abstract microsoft excelm excel einwohner smallliste staat territorien small unsekretariat schatzung world population prospects abgerufen bevdicht smallliste staat bip internetquell titelworld economic outlook database october werkworld economic outlook database hrsg international abruf billion usd smallliste land billion usd smallliste land usd smallliste land pro usd smallliste land pro biperweiteren total total small index menschlich menschlich vereint nation titeltable human development index and its component sammelwerkhuman development report verlagunited nation development programm ortnew york datumisbnspracheenseiten online wahrung indisch rupie unabhangigkeit ust br vereinigt nationalhymne jana gana manabr dateijana gana mana uar tag republik indientag republikbr ust ober gandhi zeitzone kfzkennzeich kfzkennzeich iso iso inin ind internettld telefonvorwahl bildlage india the globe claimed and defacto hatched asia bild indien bildbeschreibung karte bevzunahme steigen webarchivurl wayback textthe world fact book india central intelligence agency cia abgerufen ust positionskarte indien width floatright caption positionskarte indien position regionin positionskarte indien position regionin positionskarte indien position regionin positionskarte indien position regionin positionskarte indien position regionin positionskarte indien position regionin positionskarte indien position regionin positionskarte indien position regionin positionskarte indien position regionin positionskarte indien position regionin positionskarte indien position regionin positionskarte indien position regionin positionskarte indien position regionin positionskarte indien position regionin positionskarte indien position regionin positionskarte indien position regionin positionskarte indien position regionin positionskarte indien position regionin labelsmallkochi positionskarte indien position regionin positionskarte indien position regionin positionskarte indien position regionin positionskarte indien marksize position regionin positionskarte position chinaspan stylecolorvolksrepublik positionskarte position positionskarte position positionskarte position labelnepalspan positionskarte position positionskarte position stylecolorbanglabr positionskarte position labelsmallsri lankaspan stylecolorsribr positionskarte position labelindisch ozeanspan stylecolordbindischerbr positionskarte positionbottom positionskarte positionbottom positionskarte positionbottom indien ipaˈɪndiən eigennamen his bharat ganarajya ens republic of india staat indien umfasst groß teil indisch himalaya bilden naturlich nordgrenze indiens suden umschließen indisch ozeanindisch ozean ien grenzen pakistan volksrepublik chinachinesisch autonome gebiet tibetautonome gebiet tibet nepal bhutan myanmar tere nachbarstaat indisch ozean sri lanka sichtlich landesflachen indien liste staat land etwa milliarde einwohner indien seit april volksrepublik china liste staat territorien staat erde somit demokratie bundeszentrale politisch internetquell titelindien einwohner mehr china fortschreitend modernis ...

# %%
df_pp = pd.DataFrame(preprocessed_content.items())
df_pp = df_pp.rename({0: "pageid", 1:"preprocessed_content"}, axis = 1)

# %%
df_pp.head()
# Out:
#     pageid                               preprocessed_content
# 0   490244  scuola raffaelraffael schule athen idealisiert...
# 1  3221050  ort deutsch name name landessprache wappe coat...
# 2     1428  dateidanimarca xiii secolo plinio historia min...
# 3     2677  nameamtssprach namedeutsch bildflagge flag of ...
# 4     2391  land bedeutung sehen indien nameamtssprach spa...

# %%
df_pp.to_csv("./all_preprocessed_excellent_article_as_text.csv")
